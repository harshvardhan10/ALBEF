# %%
#==========================================================================
# JUPYTER PATH STUFF. Not present in the main script coz does not affect it
# =========================================================================

import os
from pathlib import Path
import sys

os.chdir("..")


root = Path().resolve()
while root != root.parent:
    if (root / "scripts").is_dir():
        sys.path.insert(0, str(root))
        print("Added to sys.path:", root)
        break
    root = root.parent
else:
    raise RuntimeError("Could not find 'scripts' directory above this notebook")
# Out:
# Added to sys.path: /home/woody/iwi5/iwi5362h/ALBEF

# %%
import numpy as np
import pandas as pd
import torch

# %%
def load_meta(meta_csv):
    """
    Load VinDr meta CSV with columns: image_id, dim0, dim1
    Returns dict: image_id -> (orig_height, orig_width)
    """
    df = pd.read_csv(meta_csv)
    return {r["image_id"]: (int(r["dim0"]), int(r["dim1"])) for _, r in df.iterrows()}


def scale_box_to_256(r, orig_h, orig_w, target_size=256):
    """
    Scale a GT box from original resolution to target_size x target_size space.

    r: DataFrame row with x_min, y_min, x_max, y_max in original px.
    Returns (x_min_256, y_min_256, x_max_256, y_max_256) as ints, clamped to [0, target_size-1].
    """
    scale_x = float(target_size) / float(orig_w)
    scale_y = float(target_size) / float(orig_h)

    x_min = r["x_min"] * scale_x
    y_min = r["y_min"] * scale_y
    x_max = r["x_max"] * scale_x
    y_max = r["y_max"] * scale_y

    # convert to int indices for slicing heatmaps
    x_min_i = int(np.floor(x_min))
    y_min_i = int(np.floor(y_min))
    x_max_i = int(np.ceil(x_max))
    y_max_i = int(np.ceil(y_max))

    # clamp
    x_min_i = max(0, min(target_size - 1, x_min_i))
    y_min_i = max(0, min(target_size - 1, y_min_i))
    x_max_i = max(0, min(target_size, x_max_i))
    y_max_i = max(0, min(target_size, y_max_i))

    # ensure at least 1 pixel in each dimension
    if x_max_i <= x_min_i:
        x_max_i = min(target_size, x_min_i + 1)
    if y_max_i <= y_min_i:
        y_max_i = min(target_size, y_min_i + 1)

    return x_min_i, y_min_i, x_max_i, y_max_i


def compute_box_stats_for_heatmap(
    heatmap: np.ndarray,
    box_coords,
    percentiles,
):
    """
    heatmap: (H, W) in [0,1]
    box_coords: (x_min, y_min, x_max, y_max) in 256x256 indices
    percentiles: list of percentiles to evaluate (e.g. [90,95,99])

    Returns a dict with:
      - mean_in_box
      - max_in_box
      - mean_global
      - For each p in percentiles:
          top{p}_coverage
          top{p}_recall
    """
    H, W = heatmap.shape
    x_min, y_min, x_max, y_max = box_coords

    # region inside box
    box_region = heatmap[y_min:y_max, x_min:x_max]
    mean_in_box = float(box_region.mean())
    max_in_box = float(box_region.max())

    mean_global = float(heatmap.mean())

    results = {
        "mean_in_box": mean_in_box,
        "max_in_box": max_in_box,
        "mean_global": mean_global,
    }

    box_area = box_region.size  # number of pixels in box

    # Flatten for percentile computation
    flat = heatmap.reshape(-1)

    for p in percentiles:
        thr = np.percentile(flat, p)
        mask = (heatmap >= thr).astype(np.float32)  # 1 on top-p% pixels

        mask_area = mask.sum()

        # intersection: pixels in mask AND in box
        mask_box = mask[y_min:y_max, x_min:x_max]
        inter = mask_box.sum()

        if mask_area > 0:
            coverage = float(inter / mask_area)       # how much of top-p% area lies inside box
        else:
            coverage = 0.0

        recall = float(inter / box_area) if box_area > 0 else 0.0  # how much of box is "hot"

        results[f"top{p}_coverage"] = coverage
        results[f"top{p}_recall"] = recall

    return results

# %%
annotations_csv = Path("/home/woody/iwi5/iwi5362h/data/vindr_cxr/annotations/annotations_test.csv")
meta_csv = Path("/home/woody/iwi5/iwi5362h/data/vindr_cxr/test_meta.csv")
heatmaps_root = Path("/home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn")

# %%
df_ann = pd.read_csv(annotations_csv)
meta = load_meta(meta_csv)

# %%
percentiles = [90, 95, 99]

# %%
# ------------------ Loop over GT boxes ------------------
records = []
missing_heatmap_images = set()

for idx, r in df_ann.iterrows():
    image_id = r["image_id"]
    label = r["class_name"]

    if image_id not in meta:
        print(f"[WARN] image_id={image_id} not found in meta CSV; skipping.")
        continue

    # Skip boxes with invalid / NaN coordinates (for No Findings)
    if any(pd.isna(r[col]) for col in ["x_min", "y_min", "x_max", "y_max"]):
        print(f"[WARN] NaN box coordinates for image_id={image_id}, label={label} → skipping GT box.")
        continue

    orig_h, orig_w = meta[image_id]

    hm_path = heatmaps_root / f"{image_id}.pt"
    if not hm_path.exists():
        if image_id not in missing_heatmap_images:
            print(f"[WARN] Missing heatmap file for {image_id}: {hm_path}")
            missing_heatmap_images.add(image_id)
        continue

    heatmaps = torch.load(hm_path, map_location="cpu")
    if label not in heatmaps:
        print(f"[WARN] No heatmap for label '{label}' in {hm_path.name}; skipping this GT box.")
        continue

    hm_tensor = heatmaps[label].float()
    # Normalization (defensive; should already be ~[0,1])
    if hm_tensor.max() > hm_tensor.min():
        hm_tensor = (hm_tensor - hm_tensor.min()) / (hm_tensor.max() - hm_tensor.min())
    else:
        hm_tensor = torch.zeros_like(hm_tensor)

    heatmap = hm_tensor.detach().cpu().numpy()
    H, W = heatmap.shape
    if H != 256 or W != 256:
        raise ValueError(f"Expected heatmap 256x256, got {H}x{W} for {image_id}, label={label}")

    # Scale GT box to 256x256
    box_256 = scale_box_to_256(r, orig_h=orig_h, orig_w=orig_w, target_size=256)

    stats = compute_box_stats_for_heatmap(
        heatmap=heatmap,
        box_coords=box_256,
        percentiles=percentiles,
    )

    row_record = {
        "image_id": image_id,
        "label": label,
        "x_min_256": box_256[0],
        "y_min_256": box_256[1],
        "x_max_256": box_256[2],
        "y_max_256": box_256[3],
    }
    row_record.update(stats)
    records.append(row_record)

    if (idx + 1) % 500 == 0 or (idx + 1) == len(df_ann):
        print(f"[Eval] Processed {idx + 1}/{len(df_ann)} GT boxes")

if not records:
    print("[Result] No records to evaluate. Check inputs / filters.")

df_res = pd.DataFrame(records)
print("\n[Result] Overall statistics:")
print(df_res.describe())

# ------------------ Per-label summaries ------------------
print("\n[Result] Per-label statistics (mean over boxes):")
group_cols = ["mean_in_box", "max_in_box", "mean_global"]
for p in percentiles:
    group_cols.append(f"top{p}_coverage")
    group_cols.append(f"top{p}_recall")

df_label = df_res.groupby("label")[group_cols].mean().sort_values("mean_in_box", ascending=False)
print(df_label)
# Out:
# [WARN] No heatmap for label 'Calcification' in e0dc2e79105ad93532484e956ef8a71a.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in e0dc2e79105ad93532484e956ef8a71a.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pneumothorax' in e0dc2e79105ad93532484e956ef8a71a.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pneumothorax' in e0dc2e79105ad93532484e956ef8a71a.pt; skipping this GT box.
# [WARN] No heatmap for label 'Atelectasis' in e0dc2e79105ad93532484e956ef8a71a.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pneumothorax' in e0dc2e79105ad93532484e956ef8a71a.pt; skipping this GT box.
# [WARN] No heatmap for label 'Infiltration' in 0aed23e64ebdea798486056b4f174424.pt; skipping this GT box.
# [WARN] No heatmap for label 'Consolidation' in 0aed23e64ebdea798486056b4f174424.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in aa15cfcfca7605465ca0513902738b95.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in aa15cfcfca7605465ca0513902738b95.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in aa15cfcfca7605465ca0513902738b95.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 665c4a6d2693dc0286d65ab479c9b169.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 665c4a6d2693dc0286d65ab479c9b169.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in 42da2c134b53cb5594774d3d29faac59.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in 42da2c134b53cb5594774d3d29faac59.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in c7179539654a1b3b7977e56e7e3009d5.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in bfd1974dc9778aadb407a11b57ab748f.pt; skipping this GT box.
# [WARN] No heatmap for label 'Other lesion' in 618777b8305b062583337d9a6b7a3d4e.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 618777b8305b062583337d9a6b7a3d4e.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in 618777b8305b062583337d9a6b7a3d4e.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in e54b5a593bc03c789ecdc18d8270964e.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in e54b5a593bc03c789ecdc18d8270964e.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in e54b5a593bc03c789ecdc18d8270964e.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in e54b5a593bc03c789ecdc18d8270964e.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 3019aec706bd013e1e3348564fbfd086.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 3019aec706bd013e1e3348564fbfd086.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 3019aec706bd013e1e3348564fbfd086.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 3019aec706bd013e1e3348564fbfd086.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in 3019aec706bd013e1e3348564fbfd086.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in 3019aec706bd013e1e3348564fbfd086.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 3019aec706bd013e1e3348564fbfd086.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 3019aec706bd013e1e3348564fbfd086.pt; skipping this GT box.
# [WARN] No heatmap for label 'Mediastinal shift' in 3019aec706bd013e1e3348564fbfd086.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in efbe54fcf4bdab5041ecdf15af5fcd52.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in efbe54fcf4bdab5041ecdf15af5fcd52.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in 40497da14aafc428210b623fc8445288.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 934e2731a86f3a6d750f7f7d9eaea85c.pt; skipping this GT box.
# [WARN] No heatmap for label 'Lung Opacity' in 934e2731a86f3a6d750f7f7d9eaea85c.pt; skipping this GT box.
# [WARN] No heatmap for label 'Lung Opacity' in 934e2731a86f3a6d750f7f7d9eaea85c.pt; skipping this GT box.
# [WARN] No heatmap for label 'Atelectasis' in 934e2731a86f3a6d750f7f7d9eaea85c.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in 91123b24b8a4c289820bbb2dc6dabdfe.pt; skipping this GT box.
# [WARN] NaN box coordinates for image_id=5c55f871429730b84a8ee275839b8aae, label=No finding → skipping GT box.
# [WARN] No heatmap for label 'Calcification' in bf754344a692a87c08c480dccf75e0c6.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in bf754344a692a87c08c480dccf75e0c6.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in bf754344a692a87c08c480dccf75e0c6.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 6cbbbc0e77251e60d6f4af673cc19e2a.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in 6cbbbc0e77251e60d6f4af673cc19e2a.pt; skipping this GT box.
# [WARN] No heatmap for label 'Atelectasis' in 6cbbbc0e77251e60d6f4af673cc19e2a.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in 9b609fc8e82081f4ac5bf83b8a0fbc5c.pt; skipping this GT box.
# [WARN] No heatmap for label 'Consolidation' in 9b609fc8e82081f4ac5bf83b8a0fbc5c.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in 31b4de538dd6272b05e295142c5ccc2a.pt; skipping this GT box.
# [WARN] No heatmap for label 'Other lesion' in 31b4de538dd6272b05e295142c5ccc2a.pt; skipping this GT box.
# [WARN] No heatmap for label 'Consolidation' in 97f0ad3b3ccbfc848bf9cc7e1a76377c.pt; skipping this GT box.
# [WARN] No heatmap for label 'Consolidation' in 97f0ad3b3ccbfc848bf9cc7e1a76377c.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 97f0ad3b3ccbfc848bf9cc7e1a76377c.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in 218e819ed8c0fe25c92ee7f1d5b993c7.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in 218e819ed8c0fe25c92ee7f1d5b993c7.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 6cd9d28658e91fe717e33e2f8b10e81a.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 6cd9d28658e91fe717e33e2f8b10e81a.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 6cd9d28658e91fe717e33e2f8b10e81a.pt; skipping this GT box.
# [WARN] No heatmap for label 'Other lesion' in 6cd9d28658e91fe717e33e2f8b10e81a.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in b4e78fa47b3675c8de1ceae320bc4bf9.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in b4e78fa47b3675c8de1ceae320bc4bf9.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in b4e78fa47b3675c8de1ceae320bc4bf9.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in b4e78fa47b3675c8de1ceae320bc4bf9.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in b4e78fa47b3675c8de1ceae320bc4bf9.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in b4e78fa47b3675c8de1ceae320bc4bf9.pt; skipping this GT box.
# [WARN] No heatmap for label 'Lung Opacity' in ae764a3ffd1b0317e4496637b3708a20.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in ae764a3ffd1b0317e4496637b3708a20.pt; skipping this GT box.
# [WARN] No heatmap for label 'Other lesion' in ae764a3ffd1b0317e4496637b3708a20.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in 8523b847bfffd922ccc8748667cb4a6b.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 8523b847bfffd922ccc8748667cb4a6b.pt; skipping this GT box.
# [WARN] NaN box coordinates for image_id=4dcaf539b6497ad02f2734e1b78c9678, label=No finding → skipping GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in 774a27811e9fea0a7551f17f0b00130c.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in 774a27811e9fea0a7551f17f0b00130c.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in f890e83cfa9198db05bc36b3ffc14c4d.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in b7806ab0cae2d0a9e40e009a354e4712.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 9dac311de884273b67f2623ce139e248.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in 9dac311de884273b67f2623ce139e248.pt; skipping this GT box.
# [WARN] No heatmap for label 'Consolidation' in 9dac311de884273b67f2623ce139e248.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 57a1a6b02398e336508aa57ecf962e74.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 57a1a6b02398e336508aa57ecf962e74.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 57a1a6b02398e336508aa57ecf962e74.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in 57a1a6b02398e336508aa57ecf962e74.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in 552e53af89d7ae4c482cb935ac1542b7.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in 552e53af89d7ae4c482cb935ac1542b7.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 552e53af89d7ae4c482cb935ac1542b7.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 552e53af89d7ae4c482cb935ac1542b7.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in cf53ffbeb2ef098612d71ea84d97ebc4.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in cf53ffbeb2ef098612d71ea84d97ebc4.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in e52b5e6afc1c45823626dfc0b0c07a8c.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in e52b5e6afc1c45823626dfc0b0c07a8c.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in e52b5e6afc1c45823626dfc0b0c07a8c.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in e52b5e6afc1c45823626dfc0b0c07a8c.pt; skipping this GT box.
# [WARN] No heatmap for label 'Enlarged PA' in 937a353dd57519c0757ce2da3ae2bdc2.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pneumothorax' in 7aa301c90a61603f9b5e2e05a88b4204.pt; skipping this GT box.
# [WARN] No heatmap for label 'Atelectasis' in 7aa301c90a61603f9b5e2e05a88b4204.pt; skipping this GT box.
# [WARN] No heatmap for label 'Other lesion' in 7aa301c90a61603f9b5e2e05a88b4204.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 53ae3d1a464529cb387ce44aa655846f.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 53ae3d1a464529cb387ce44aa655846f.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 53ae3d1a464529cb387ce44aa655846f.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 2021c6c746096cd28002e71ceb992c69.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 2021c6c746096cd28002e71ceb992c69.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in 2021c6c746096cd28002e71ceb992c69.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 2021c6c746096cd28002e71ceb992c69.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 2021c6c746096cd28002e71ceb992c69.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 2021c6c746096cd28002e71ceb992c69.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in 2021c6c746096cd28002e71ceb992c69.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 2021c6c746096cd28002e71ceb992c69.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 2021c6c746096cd28002e71ceb992c69.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in 7073d58de75ee80e16ec3a4458349f90.pt; skipping this GT box.
# [WARN] No heatmap for label 'Rib fracture' in 7073d58de75ee80e16ec3a4458349f90.pt; skipping this GT box.
# [WARN] No heatmap for label 'Lung Opacity' in 7073d58de75ee80e16ec3a4458349f90.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 7073d58de75ee80e16ec3a4458349f90.pt; skipping this GT box.
# [WARN] No heatmap for label 'Consolidation' in 395f2f015b69bcf2e58fcba55ecb6793.pt; skipping this GT box.
# [WARN] No heatmap for label 'Lung cavity' in 395f2f015b69bcf2e58fcba55ecb6793.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 379350d6cca599b6a09c5387c9160aad.pt; skipping this GT box.
# [WARN] No heatmap for label 'Lung cavity' in 379350d6cca599b6a09c5387c9160aad.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 379350d6cca599b6a09c5387c9160aad.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 379350d6cca599b6a09c5387c9160aad.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 379350d6cca599b6a09c5387c9160aad.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 379350d6cca599b6a09c5387c9160aad.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 379350d6cca599b6a09c5387c9160aad.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 379350d6cca599b6a09c5387c9160aad.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in 134214ffc7f507842719617ecd5bfc52.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 134214ffc7f507842719617ecd5bfc52.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 588634981efe8a011372632c6d76eea0.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in 4b19ca098b479dd60cc2288ab680e3eb.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 4b19ca098b479dd60cc2288ab680e3eb.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 4b19ca098b479dd60cc2288ab680e3eb.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in 5beee832c007826c93c25ba287ee4d48.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in 5beee832c007826c93c25ba287ee4d48.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in 5beee832c007826c93c25ba287ee4d48.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in bdf81a571d4164c54e1d57e870bab752.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in bdf81a571d4164c54e1d57e870bab752.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in fb96a81650614fc467bc6e5af94543b8.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in fb96a81650614fc467bc6e5af94543b8.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in fb96a81650614fc467bc6e5af94543b8.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 4c5cda3481350033d181e879d29f0135.pt; skipping this GT box.
# [WARN] No heatmap for label 'Other lesion' in 4c5cda3481350033d181e879d29f0135.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 39949d5d2d8855e391b87d8a932b5aaf.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 39949d5d2d8855e391b87d8a932b5aaf.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in c826c6a366c7ff0a6a2b202e423b2353.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in c826c6a366c7ff0a6a2b202e423b2353.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in c826c6a366c7ff0a6a2b202e423b2353.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in c826c6a366c7ff0a6a2b202e423b2353.pt; skipping this GT box.
# [WARN] No heatmap for label 'Atelectasis' in 439dc69a4c208bef639794335fc7e8aa.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 439dc69a4c208bef639794335fc7e8aa.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in 439dc69a4c208bef639794335fc7e8aa.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in 439dc69a4c208bef639794335fc7e8aa.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in 439dc69a4c208bef639794335fc7e8aa.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in 439dc69a4c208bef639794335fc7e8aa.pt; skipping this GT box.
# [WARN] No heatmap for label 'Other lesion' in 878e449975ff3b3fe915c976e7b8349e.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 878e449975ff3b3fe915c976e7b8349e.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 878e449975ff3b3fe915c976e7b8349e.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in 878e449975ff3b3fe915c976e7b8349e.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 2127bbf73b1d0f150ca12bfa5ca2b91d.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 2127bbf73b1d0f150ca12bfa5ca2b91d.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in 2127bbf73b1d0f150ca12bfa5ca2b91d.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in 2127bbf73b1d0f150ca12bfa5ca2b91d.pt; skipping this GT box.
# [WARN] No heatmap for label 'Other lesion' in 2127bbf73b1d0f150ca12bfa5ca2b91d.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 2eae70b57d68947a20d6d0cc8f9f2e58.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 2eae70b57d68947a20d6d0cc8f9f2e58.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 2eae70b57d68947a20d6d0cc8f9f2e58.pt; skipping this GT box.
# [WARN] No heatmap for label 'Consolidation' in 885cb27d4cf51dc3aa6fa71b3aff08d8.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 67f342c22873acfcf19d3b6501e53802.pt; skipping this GT box.
# [WARN] No heatmap for label 'Atelectasis' in 67f342c22873acfcf19d3b6501e53802.pt; skipping this GT box.
# [WARN] NaN box coordinates for image_id=58baa9b0269a2987f5475a554033c4b1, label=No finding → skipping GT box.
# [WARN] No heatmap for label 'Calcification' in 754d373b98400f931d1070778c25e2d2.pt; skipping this GT box.
# [WARN] No heatmap for label 'Lung Opacity' in 754d373b98400f931d1070778c25e2d2.pt; skipping this GT box.
# [WARN] NaN box coordinates for image_id=36aa7cdf317c33edc514ef43814d4c9b, label=No finding → skipping GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in e154120eb7eb235ddb471c94deff2ee6.pt; skipping this GT box.
# [WARN] No heatmap for label 'Lung Opacity' in e154120eb7eb235ddb471c94deff2ee6.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in e154120eb7eb235ddb471c94deff2ee6.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in e154120eb7eb235ddb471c94deff2ee6.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in 7a74f4e463b72f018838f26cf7aabdf2.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 7a74f4e463b72f018838f26cf7aabdf2.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in ee29da033302291107e61a87de63aee3.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in ee29da033302291107e61a87de63aee3.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in cf46419b1583aff3e8ca76705dd5e584.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in cf46419b1583aff3e8ca76705dd5e584.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in cf46419b1583aff3e8ca76705dd5e584.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in f688540fa7c5a58e3f5f0d0908a15164.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in f688540fa7c5a58e3f5f0d0908a15164.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in f688540fa7c5a58e3f5f0d0908a15164.pt; skipping this GT box.
# [WARN] No heatmap for label 'Atelectasis' in 8b92de834e67f5a072af66d59aacc825.pt; skipping this GT box.
# [WARN] No heatmap for label 'Enlarged PA' in 0e68445ef76f193664ea018630544d95.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 0e68445ef76f193664ea018630544d95.pt; skipping this GT box.
# [WARN] No heatmap for label 'Atelectasis' in 0e68445ef76f193664ea018630544d95.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 03f00327702f48c4b6726a0e1649a157.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in 940635db4ae037a40c8a95a81de062d6.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in 940635db4ae037a40c8a95a81de062d6.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in 9aec9e6e04ea05b1715969f8f20c86bc.pt; skipping this GT box.
# [WARN] No heatmap for label 'Atelectasis' in 8d612aaeaf1b5a01971cbdba49b37fdb.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in 7f15c433dbc249a491b86b27e5a6c180.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 7f15c433dbc249a491b86b27e5a6c180.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in 7f15c433dbc249a491b86b27e5a6c180.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 7f15c433dbc249a491b86b27e5a6c180.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in ba1cf5031a6f73a997901af57110de77.pt; skipping this GT box.
# [WARN] No heatmap for label 'Consolidation' in ba1cf5031a6f73a997901af57110de77.pt; skipping this GT box.
# [WARN] No heatmap for label 'Consolidation' in ba1cf5031a6f73a997901af57110de77.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in 0ecaae458f6ca4c8f4dd9975d62a6fa4.pt; skipping this GT box.
# [WARN] No heatmap for label 'Other lesion' in 0ecaae458f6ca4c8f4dd9975d62a6fa4.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in 287422bed1d9d153387361889619abed.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in bb3cb6e89c003ad4be9c6141b1d66723.pt; skipping this GT box.
# [WARN] No heatmap for label 'Atelectasis' in bb3cb6e89c003ad4be9c6141b1d66723.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in bb3cb6e89c003ad4be9c6141b1d66723.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in bb3cb6e89c003ad4be9c6141b1d66723.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in a59c21bc96c0d0c599ba2447ce946bde.pt; skipping this GT box.
# [WARN] No heatmap for label 'Consolidation' in a59c21bc96c0d0c599ba2447ce946bde.pt; skipping this GT box.
# [WARN] No heatmap for label 'Lung Opacity' in a59c21bc96c0d0c599ba2447ce946bde.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in 27d34a0e721626ef60aeb17cb39e8196.pt; skipping this GT box.
# [WARN] No heatmap for label 'Other lesion' in 27d34a0e721626ef60aeb17cb39e8196.pt; skipping this GT box.
# [WARN] No heatmap for label 'Other lesion' in 27d34a0e721626ef60aeb17cb39e8196.pt; skipping this GT box.
# [WARN] No heatmap for label 'Other lesion' in 27d34a0e721626ef60aeb17cb39e8196.pt; skipping this GT box.
# [WARN] No heatmap for label 'Lung Opacity' in 27d34a0e721626ef60aeb17cb39e8196.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 27d34a0e721626ef60aeb17cb39e8196.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 27d34a0e721626ef60aeb17cb39e8196.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in 8a28453b44f960e96195ef63a19eef4d.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 8a28453b44f960e96195ef63a19eef4d.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in ef5443eef2359a9882e61754855887cb.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in ef5443eef2359a9882e61754855887cb.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in ef5443eef2359a9882e61754855887cb.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in ef5443eef2359a9882e61754855887cb.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in ef5443eef2359a9882e61754855887cb.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in ef5443eef2359a9882e61754855887cb.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in d0715b16ff3a8071968d4f7adff9c339.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in d0715b16ff3a8071968d4f7adff9c339.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in d0715b16ff3a8071968d4f7adff9c339.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in d0715b16ff3a8071968d4f7adff9c339.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in b1876d26a3f3cc44a8c667aa2a8a972c.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in b1876d26a3f3cc44a8c667aa2a8a972c.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in b1876d26a3f3cc44a8c667aa2a8a972c.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 24151df5b3919093e2c97bc6647260fb.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 24151df5b3919093e2c97bc6647260fb.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in 24151df5b3919093e2c97bc6647260fb.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in a87c6ab4132c0ef29ebf51bc418ce921.pt; skipping this GT box.
# [WARN] No heatmap for label 'Consolidation' in a87c6ab4132c0ef29ebf51bc418ce921.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in 8738f1843ea1425fdb36e2b0fac23626.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in 8738f1843ea1425fdb36e2b0fac23626.pt; skipping this GT box.
# [WARN] No heatmap for label 'Infiltration' in 8738f1843ea1425fdb36e2b0fac23626.pt; skipping this GT box.
# [WARN] No heatmap for label 'Lung Opacity' in 8738f1843ea1425fdb36e2b0fac23626.pt; skipping this GT box.
# [WARN] No heatmap for label 'Lung Opacity' in 8738f1843ea1425fdb36e2b0fac23626.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 25f92d35866a758f4175812fe3f7f47c.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 25f92d35866a758f4175812fe3f7f47c.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in 25f92d35866a758f4175812fe3f7f47c.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 36aec3c16185942a4925ed5f272156b1.pt; skipping this GT box.
# [WARN] No heatmap for label 'Consolidation' in 36aec3c16185942a4925ed5f272156b1.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 36aec3c16185942a4925ed5f272156b1.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in 781b722e178a483b4781fbd148706b7d.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 781b722e178a483b4781fbd148706b7d.pt; skipping this GT box.
# [WARN] No heatmap for label 'Lung Opacity' in 4336126559df623f417e0cce8658d834.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in 4336126559df623f417e0cce8658d834.pt; skipping this GT box.
# [WARN] No heatmap for label 'Calcification' in 6072691c16f225c5758fd5d4750b3044.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in abbe42351ae1e98ba1bec5733e5dab40.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in abbe42351ae1e98ba1bec5733e5dab40.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in abbe42351ae1e98ba1bec5733e5dab40.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in abbe42351ae1e98ba1bec5733e5dab40.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in abbe42351ae1e98ba1bec5733e5dab40.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 1d6476853a2aaaf281c1be2e2584e383.pt; skipping this GT box.
# [WARN] No heatmap for label 'Infiltration' in 1d6476853a2aaaf281c1be2e2584e383.pt; skipping this GT box.
# [WARN] No heatmap for label 'Infiltration' in 1d6476853a2aaaf281c1be2e2584e383.pt; skipping this GT box.
# [WARN] No heatmap for label 'Infiltration' in 1d6476853a2aaaf281c1be2e2584e383.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 1d6476853a2aaaf281c1be2e2584e383.pt; skipping this GT box.
# [WARN] No heatmap for label 'Atelectasis' in ce5a5ce9eb9ca67da16e9c8677a056e4.pt; skipping this GT box.
# [WARN] No heatmap for label 'Consolidation' in f706b17da0996dc76d0ab344fd0b2ae0.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in f706b17da0996dc76d0ab344fd0b2ae0.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 14d90cb65cec1138f6bcb97bd7892393.pt; skipping this GT box.
# [WARN] No heatmap for label 'ILD' in 14d90cb65cec1138f6bcb97bd7892393.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 14d90cb65cec1138f6bcb97bd7892393.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 14d90cb65cec1138f6bcb97bd7892393.pt; skipping this GT box.
# [WARN] No heatmap for label 'Nodule/Mass' in 14d90cb65cec1138f6bcb97bd7892393.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 171dff98d336340bca7e12645e0a5a41.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 171dff98d336340bca7e12645e0a5a41.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in 171dff98d336340bca7e12645e0a5a41.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pleural thickening' in 171dff98d336340bca7e12645e0a5a41.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 171dff98d336340bca7e12645e0a5a41.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 171dff98d336340bca7e12645e0a5a41.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 171dff98d336340bca7e12645e0a5a41.pt; skipping this GT box.
# [WARN] No heatmap for label 'Pulmonary fibrosis' in 171dff98d336340bca7e12645e0a5a41.pt; skipping this GT box.
# [WARN] No heatmap for label 'Aortic enlargement' in ca40cec6911dc19ae5a22ef7b474eea9.pt; skipping this GT box.
# [WARN] Missing heatmap file for 7e6998dc71a747ce227b50463c4e79b4: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/7e6998dc71a747ce227b50463c4e79b4.pt
# [WARN] Missing heatmap file for a7b8a9e921ea304362918523cc3529ef: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/a7b8a9e921ea304362918523cc3529ef.pt
# [WARN] Missing heatmap file for dd7e2b3e4d751779e5a5f61e827f6f7b: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/dd7e2b3e4d751779e5a5f61e827f6f7b.pt
# [WARN] Missing heatmap file for 730f25f4ac6b4fd10d9cf582494c911e: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/730f25f4ac6b4fd10d9cf582494c911e.pt
# [WARN] Missing heatmap file for 0ccde8751e5952ea6bb047378dcbabba: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/0ccde8751e5952ea6bb047378dcbabba.pt
# [WARN] Missing heatmap file for d65bd4d5a6fae0e0f6833e1a7dd48399: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/d65bd4d5a6fae0e0f6833e1a7dd48399.pt
# [WARN] Missing heatmap file for 2b2810284313c5547241b38668f67b2c: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/2b2810284313c5547241b38668f67b2c.pt
# [WARN] Missing heatmap file for 41143299da79b12a5a6d8c4456c68aa7: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/41143299da79b12a5a6d8c4456c68aa7.pt
# [WARN] Missing heatmap file for d01381128975c8bf4dbfd2bf79bd6de1: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/d01381128975c8bf4dbfd2bf79bd6de1.pt
# [WARN] Missing heatmap file for d284e83f3baf1f572284e30999dc013c: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/d284e83f3baf1f572284e30999dc013c.pt
# [WARN] Missing heatmap file for 1417df96cf0ef3878d5be9cbf5b03b0b: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/1417df96cf0ef3878d5be9cbf5b03b0b.pt
# [WARN] Missing heatmap file for 77fb399d095bb11d1344a1a114f59376: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/77fb399d095bb11d1344a1a114f59376.pt
# [WARN] Missing heatmap file for 2719b0f265ede38083eb9558a9b325dc: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/2719b0f265ede38083eb9558a9b325dc.pt
# [WARN] Missing heatmap file for 36eaf06f68d1f5eb34e2247a5ffabdb6: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/36eaf06f68d1f5eb34e2247a5ffabdb6.pt
# [WARN] Missing heatmap file for 96b106d836d2b4f16362d3a1d1f767a5: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/96b106d836d2b4f16362d3a1d1f767a5.pt
# [WARN] Missing heatmap file for c67911931c2b1daf694d97eb139a9807: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/c67911931c2b1daf694d97eb139a9807.pt
# [WARN] Missing heatmap file for cc657609a4dcf498ea39a9586d7ae9b3: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/cc657609a4dcf498ea39a9586d7ae9b3.pt
# [WARN] Missing heatmap file for e774e7f6a28e1767f2e5db7ceb01428d: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/e774e7f6a28e1767f2e5db7ceb01428d.pt
# [WARN] Missing heatmap file for 5118cbe9894006f58312565294e85556: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/5118cbe9894006f58312565294e85556.pt
# [WARN] Missing heatmap file for 1797ac887e393a0e25ebb44b3125f0c1: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/1797ac887e393a0e25ebb44b3125f0c1.pt
# [WARN] Missing heatmap file for 25e40d94f13653fcd2b829c45cb18e3f: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/25e40d94f13653fcd2b829c45cb18e3f.pt
# [WARN] Missing heatmap file for d9b150bb7eb1476c685a8c147016c0ac: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/d9b150bb7eb1476c685a8c147016c0ac.pt
# [WARN] Missing heatmap file for 9021a7769e065e341d0893fac8250f2f: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/9021a7769e065e341d0893fac8250f2f.pt
# [WARN] Missing heatmap file for 74897408dcbd69ef7c76cbbbbeb722d6: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/74897408dcbd69ef7c76cbbbbeb722d6.pt
# [WARN] Missing heatmap file for 5b26a75de620121bcdf0b76e15fbbd3f: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/5b26a75de620121bcdf0b76e15fbbd3f.pt
# [WARN] Missing heatmap file for 91fe3b729dcb9a1fe5ddc310893fd339: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/91fe3b729dcb9a1fe5ddc310893fd339.pt
# [WARN] Missing heatmap file for 5164cecc1932454bd2f467ebb4ea0650: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/5164cecc1932454bd2f467ebb4ea0650.pt
# [WARN] Missing heatmap file for b45de8c5c4a5ec655fe0d6250a45c218: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/b45de8c5c4a5ec655fe0d6250a45c218.pt
# [WARN] Missing heatmap file for c872af6db5f8dc838fcbbed78666bdd7: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/c872af6db5f8dc838fcbbed78666bdd7.pt
# [WARN] Missing heatmap file for bebbc91bc41beeb5580968fb34b7c5e2: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/bebbc91bc41beeb5580968fb34b7c5e2.pt
# [WARN] Missing heatmap file for 42480dff233be45d4fdca62069ea267f: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/42480dff233be45d4fdca62069ea267f.pt
# [WARN] Missing heatmap file for 8e3d51015dcc574507110141019bc77a: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/8e3d51015dcc574507110141019bc77a.pt
# [WARN] Missing heatmap file for 448408b2da910f68f956ba77db83bf7f: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/448408b2da910f68f956ba77db83bf7f.pt
# [WARN] Missing heatmap file for dd14fbccb38c064bdacc33391d8cca9e: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/dd14fbccb38c064bdacc33391d8cca9e.pt
# [WARN] Missing heatmap file for b6cd281d9e2086509d4aff85866aa1dc: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/b6cd281d9e2086509d4aff85866aa1dc.pt
# [WARN] Missing heatmap file for 1e87b2befde0db02bf14e75e798e4269: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/1e87b2befde0db02bf14e75e798e4269.pt
# [WARN] Missing heatmap file for 2fb8c4094b8bd6943407a071dfe6c73d: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/2fb8c4094b8bd6943407a071dfe6c73d.pt
# [WARN] NaN box coordinates for image_id=69fa47c3c46618fe8c58966a2cc66aef, label=No finding → skipping GT box.
# [WARN] Missing heatmap file for 6b94fef0e417c083388ba961b1d2786a: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/6b94fef0e417c083388ba961b1d2786a.pt
# [WARN] Missing heatmap file for 28290df9749ce386affc87de6b7c3a49: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/28290df9749ce386affc87de6b7c3a49.pt
# [WARN] Missing heatmap file for 47ce4f0300b152a5d4e22f812f747292: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/47ce4f0300b152a5d4e22f812f747292.pt
# [WARN] Missing heatmap file for 8f83a4da5d18bff5a21d5caaef7d38ae: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/8f83a4da5d18bff5a21d5caaef7d38ae.pt
# [WARN] Missing heatmap file for 77b20dccfcee611b676bbfa760f883d3: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/77b20dccfcee611b676bbfa760f883d3.pt
# [WARN] NaN box coordinates for image_id=710700d3055a746543394296d1fb736e, label=No finding → skipping GT box.
# [WARN] Missing heatmap file for c4c6b6599a13c1c914b839f7a9f79540: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/c4c6b6599a13c1c914b839f7a9f79540.pt
# [WARN] Missing heatmap file for 897bb7685ab7e0b33ffd63d8a8c602af: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/897bb7685ab7e0b33ffd63d8a8c602af.pt
# [WARN] Missing heatmap file for c61f7e35aef4b38aa85063ffbe65218e: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/c61f7e35aef4b38aa85063ffbe65218e.pt
# [WARN] Missing heatmap file for 17df698e956c640c7aad338afb841679: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/17df698e956c640c7aad338afb841679.pt
# [WARN] Missing heatmap file for a88f299e626d550027eaeb70250032ef: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/a88f299e626d550027eaeb70250032ef.pt
# [WARN] Missing heatmap file for 05711a72a0819422965daa93f30b6f75: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/05711a72a0819422965daa93f30b6f75.pt
# [WARN] Missing heatmap file for 26ca88b5b40079f5627ef686bcc945fe: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/26ca88b5b40079f5627ef686bcc945fe.pt
# [WARN] Missing heatmap file for 58d76e6dae9bbb3a24fe79f771b735a6: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/58d76e6dae9bbb3a24fe79f771b735a6.pt
# [WARN] Missing heatmap file for efa7592fab822d9a1d6dc92d31e41fa1: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/efa7592fab822d9a1d6dc92d31e41fa1.pt
# [WARN] NaN box coordinates for image_id=384ee8c20076c44adbe60bfe7e805869, label=No finding → skipping GT box.
# [WARN] Missing heatmap file for a9bfb9e92e3303005bbb9e98a86bd3c8: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/a9bfb9e92e3303005bbb9e98a86bd3c8.pt
# [WARN] Missing heatmap file for bf5ba5b99fc00f8c786977623a50b8a6: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/bf5ba5b99fc00f8c786977623a50b8a6.pt
# [WARN] Missing heatmap file for 82a05fbda7ecdf80c82d6392b4fcb309: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/82a05fbda7ecdf80c82d6392b4fcb309.pt
# [WARN] Missing heatmap file for 9112756a7e8b3ae899c07ee78f42ba65: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/9112756a7e8b3ae899c07ee78f42ba65.pt
# [WARN] Missing heatmap file for 615f0f5be81be998158659b735a3e8c8: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/615f0f5be81be998158659b735a3e8c8.pt
# [WARN] Missing heatmap file for 9bd79ff85b40084060c327b2b9ca1e81: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/9bd79ff85b40084060c327b2b9ca1e81.pt
# [WARN] Missing heatmap file for 9a9c1899b72972a4c1a6a540aa2941cf: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/9a9c1899b72972a4c1a6a540aa2941cf.pt
# [WARN] Missing heatmap file for a651f4b5a5f723845a76084017650322: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/a651f4b5a5f723845a76084017650322.pt
# [WARN] Missing heatmap file for d709c132746f0409128eaa1c87a9a274: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/d709c132746f0409128eaa1c87a9a274.pt
# [WARN] Missing heatmap file for 5d4e0afb1579da54bc7a06f1fe159349: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/5d4e0afb1579da54bc7a06f1fe159349.pt
# [WARN] Missing heatmap file for 3d88da32e0b7971e4f1bb1aa684a038a: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/3d88da32e0b7971e4f1bb1aa684a038a.pt
# [WARN] Missing heatmap file for 1c04f08e163f0fdb38461013b2f6f9b9: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/1c04f08e163f0fdb38461013b2f6f9b9.pt
# [WARN] Missing heatmap file for 45f407b266655c8d3faf9bd6faa9a6d2: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/45f407b266655c8d3faf9bd6faa9a6d2.pt
# [WARN] Missing heatmap file for 871e8ae9dc52f1fd45a7cd3068c71d2e: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/871e8ae9dc52f1fd45a7cd3068c71d2e.pt
# [WARN] Missing heatmap file for 057afd48abd153972bb91397b71b66b8: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/057afd48abd153972bb91397b71b66b8.pt
# [WARN] Missing heatmap file for a6f29ff09ae2e8a11cf1e151471fdcba: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/a6f29ff09ae2e8a11cf1e151471fdcba.pt
# [WARN] Missing heatmap file for 202dc97c4b3ec7e50f4813456938500a: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/202dc97c4b3ec7e50f4813456938500a.pt
# [WARN] Missing heatmap file for 76482dd89d7d8ea3650e9a0b8e01aba6: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/76482dd89d7d8ea3650e9a0b8e01aba6.pt
# [WARN] Missing heatmap file for 29fc11e345d3a084f33fda5c43686076: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/29fc11e345d3a084f33fda5c43686076.pt
# [WARN] Missing heatmap file for b514266c17d677f96256830c911cd360: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/b514266c17d677f96256830c911cd360.pt
# [WARN] Missing heatmap file for 78920201559a84ae65d928a6167b73e8: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/78920201559a84ae65d928a6167b73e8.pt
# [WARN] Missing heatmap file for aedc1feb3dafbc2344ae4daa908fa35a: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/aedc1feb3dafbc2344ae4daa908fa35a.pt
# [WARN] Missing heatmap file for a40ebf6bbcafde17ab85ba720de1e686: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/a40ebf6bbcafde17ab85ba720de1e686.pt
# [WARN] Missing heatmap file for 889347926c284c6c61234b357153d327: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/889347926c284c6c61234b357153d327.pt
# [WARN] Missing heatmap file for 8bf191972855f263e27d2239d753e622: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/8bf191972855f263e27d2239d753e622.pt
# [WARN] Missing heatmap file for 4b4d890639634f5cc8aaefc9fed962ca: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/4b4d890639634f5cc8aaefc9fed962ca.pt
# [WARN] Missing heatmap file for a113218469475fef9827360a2f850b3f: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/a113218469475fef9827360a2f850b3f.pt
# [WARN] Missing heatmap file for 41e182efd77dc26282b2fffb91ddea9c: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/41e182efd77dc26282b2fffb91ddea9c.pt
# [WARN] Missing heatmap file for b239daece54519264624cf61e858717f: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/b239daece54519264624cf61e858717f.pt
# [WARN] Missing heatmap file for ec84efcda776fb18bf86866e11e12832: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/ec84efcda776fb18bf86866e11e12832.pt
# [WARN] Missing heatmap file for 8ea15d8dffaccc803d343596092354b5: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/8ea15d8dffaccc803d343596092354b5.pt
# [WARN] Missing heatmap file for 5a719936747485b2902623a89643a508: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/5a719936747485b2902623a89643a508.pt
# [WARN] Missing heatmap file for 0d61bab6add9d96f656dbc7ee9d56e23: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/0d61bab6add9d96f656dbc7ee9d56e23.pt
# [WARN] Missing heatmap file for e4e32ce0e061d700c0afda13faa45b1d: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/e4e32ce0e061d700c0afda13faa45b1d.pt
# [WARN] Missing heatmap file for 3c22b17493566a9bca5ac33f0cd0b42f: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/3c22b17493566a9bca5ac33f0cd0b42f.pt
# [WARN] Missing heatmap file for 9055b296acf42185d29edd60dfdc6c50: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/9055b296acf42185d29edd60dfdc6c50.pt
# [WARN] Missing heatmap file for dc7b7968067de76704074fd9e173ebdf: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/dc7b7968067de76704074fd9e173ebdf.pt
# [WARN] Missing heatmap file for 7bab78cfe1dc3376741a24ac708d75be: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/7bab78cfe1dc3376741a24ac708d75be.pt
# [WARN] Missing heatmap file for 9d55051f2ad55edc96612d7d28dfd472: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/9d55051f2ad55edc96612d7d28dfd472.pt
# [WARN] Missing heatmap file for 6e911d2832e14bb624a486bea52220d6: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/6e911d2832e14bb624a486bea52220d6.pt
# [WARN] Missing heatmap file for 20d208807c641afba1698d8f35aa8713: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/20d208807c641afba1698d8f35aa8713.pt
# [WARN] Missing heatmap file for 46f349b7cabf56c2c2d9c1d069f8c564: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/46f349b7cabf56c2c2d9c1d069f8c564.pt
# [WARN] Missing heatmap file for b6f79693e9ae47422c76c434ad003fa9: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/heatmaps_grad_crossattn/b6f79693e9ae47422c76c434ad003fa9.pt
# ...
# [WARN] NaN box coordinates for image_id=caff7d83d7749c842bce12286d311164, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=e626e81df9243e43371c8881fbc6d8b7, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=7a5e63853f72b1cf6180e4d33aecbf93, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=997fdbeb9910b1d22539b9311cc565a5, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=0e2a6f637bc997be18ec30687bdc3762, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=b5da01c47f383175b34189c9e0a604fc, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=624ad6845050f024902fd3fce5402988, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=778153803200347fa9e3573824d89e8f, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=4e6269ee38f7c8afc70792e62d0a05e8, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=17eefd92847c5a56c84990047ab2d5ae, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=ff41bdfc0c7fae671caabbe6dcf071bb, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=3a14159e53495689a8b21a371aa54ef7, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=db01060306d1f3eb3ea7c1beb8be6edf, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=6ce0806845f2f73ef1665353979d581f, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=e0c6e37639776cb11ed37eb94922df25, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=ee24bfc8651524e8efeee45ff30cb532, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=61b5b9b49242ae40885781dd2c1a2cb0, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=3a0135174fe1bec08b8318fba4aa951c, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=c93f821385bd67adda8a84155a5560e9, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=4601f338b350b816ad50be7c58deed92, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=cbd0a639798ad947081a059a87ca3e94, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=17520d7b23b5a393d697ecf139b736fc, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=deb72391b998de457c5132511a3af7e1, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=86f879c042c8a2860eb6f3177d374998, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=e4c50af34882d9a1c5631007c1d2e05d, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=cdd5481fd9376b5e7828aec48799255a, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=331dd7060c9d960473535fdd82355bb0, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=69f8a7c2bc453e0c3c71442dd0c46d91, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=8861966283668b026211d4789e556e32, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=475405daeac63ae42731ddf2b8a53508, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=99f7683a4b94a0cdb5f3b98953647a47, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=5b26309e228cdffb49fee96063e2c880, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=3f311e13697f83d41f55f079232fe7ee, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=375230098adb78e73b6d162c9e30acd6, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=6490e2cf8ea994ef53c06c287d59085d, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=6ae66f1bc9c08766adb65d366a60e2b0, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=2aa621807bfa78b2fc36c1ca34962f1c, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=867fdc610019d6500f0d02205491d6b3, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=f54bd15a6816454bbd8c5306af16a730, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=3689f084f7fa4d0f6336cca39a224f22, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=2a7a59327e473f50b0fa174fe0ba6d30, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=0b2cc81ad04ca2e91f2a8626b645cad8, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=1fad8a04142b39fb650138dc933334b3, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=df229b77da3656e5264f74025b4990f2, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=6325341c36f40a4641b62c3131d82b4e, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=8665a7a54f95442fbf721f9865fd2215, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=8622b8fb70af2568eb36fe1e9bf944df, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=3cfc0bb78ca18773c9ec91ad9bbe3d4d, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=8f0e9a83c1e26189ede1bd22fd751ead, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=327f8c6c13ad1a6efefd78409c9f2191, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=923e8cd400a4e914b50f3ee0ee7297e3, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=3ba1428b5a468133d0b75b0418514c23, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=cfb23f265ba1ca551b0fbb8720e30e6d, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=b3b085d09a42cfd9d885f4abd7948b03, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=5ba94d99f827e546b59846aa66eea08c, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=5d6e9e74f44b6f359525af6c176bf9fa, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=c1d8e02bc4d3b5e14672235659c061d3, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=05e951c63e80999f13e6e09e7ec8439a, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=0764ce517782604a7b81bb6e17c798e9, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=28381c8323917ac88d571e1213a2d382, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=b31896c53faf22384b2ec503b2657139, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=5cd7b69add950d3e0fd7d6a0b84d9ce3, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=d135d69679fd7976d2d6ec01bb167f9d, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=0e36597f559be16b6304f3771082c82a, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=1264a14de4ec7c401eaf55b1440e2d20, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=f1e4ac8d6db9d986fbff411c6a314857, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=fc28fc9ede2c505c2125343c048124b6, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=f06b3e9d9422ea8de3b22d5db99913f5, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=88b95ee8ca5cf416d2d4eefe6fdda544, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=7ce84780a2d602c08c800ff2e769514c, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=8d87354fed4d79fe6e33267600d66adf, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=4d656bcd93f3e99d46fde6c2fa36e7d4, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=d5d43ffa4e64e63ccd92c40397d6b48b, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=3fe12c24bee9c864bf65441b49a53d79, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=5e9b9e927b853f5a95cd487b249e77b2, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=2249e2c552b44d15f36f05266a7d2b7c, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=b8a064a85a04c00695de94136bd58955, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=e9c690c6b50e976406e953e6cfdb7a0b, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=20d0c4e2d3473e9f1f2891f01d5edf63, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=5175798e4a23ac250b47c0c4fd83a725, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=69d19f0d8ac223581188a5adf05cd313, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=75c2894e7a12b8f12d35b1c02ab383f6, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=91a0ba6661f1216e3e0efa1da5085927, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=3aa53ed6b890f65e41d2d359912626dd, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=1d12b94b7acbeadef7d7700b50aa90d4, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=91c465dad262c2d07cc9d98ebd3126cf, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=face7d0feea230cb057697e34fcb3ad3, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=80bc7a1af89f2b8b60ed33c83ae8ed5d, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=fcdd777de2f86604758044246dd7bebb, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=9408e65cccb846a922ba24c1482d1f4e, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=f8f82030def9bc103a16dba159f0b957, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=7565b2f86dadd6aca63ab9d6a285d53d, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=cabaca5197759010eda73ad3e3f372d2, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=f1bf11a8a2164e6adc930df26a5dd75e, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=4eef841c5708308c2ff8957ebc79ae06, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=e45ce3fb58c703c15ba13efd80e95128, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=57efd697f8ed1fe9bd4c44a139b7aa66, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=d09ec8573f5c237e56bbeae80f877f18, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=c84c9afed6d26c87c30b76ae29ebd290, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=c5026a45c2acc85937d1f13c2638f97c, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=8fc6580091f8d24be3dbd700d4630833, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=60485f64a1de6c652639c3ab84fcd12f, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=d6ac4b653b357bcebaff24830d8423cb, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=528800fde9832ed21a8c8c6f45cddf14, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=90ff0f6edbdb16fdeeaf3a8471f576ff, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=3d26f5e39259810fb7a332f50bd9d867, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=54cf3b86aba7151a1bbca30db954307e, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=016bc723c3ceedb78e27ebfe7032498e, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=f734d8823f31d805567d6480513003d2, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=d668f847d1fbfef0784961b91ad913bd, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=a1c39becc9835462d84db8c51229779f, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=0e580dda54b8d1df7e3a888c41e69704, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=6fdc6a34720c31d685942b7bb44f9612, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=acb798cac2ce66c6c9b1570fab4e4adc, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=5c4202e130bd01f555e57d8503de6491, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=4fd4306bfaeb5322082642bee9ef3ff8, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=9e8a5a85012b7b8c5dd164382d93e089, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=8b9ea72de468504f3dbc3fc711f905a3, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=b6c2293402377da9dc28dc65609022f0, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=84564d34f32254f20e49bcb6ab603421, label=No finding → skipping GT box.
# [WARN] NaN box coordinates for image_id=3c0da76eb43946a1f718198ef00bea1a, label=No finding → skipping GT box.
#
# [Result] Overall statistics:
#         x_min_256   y_min_256   x_max_256   y_max_256  mean_in_box  \
# count   61.000000   61.000000   61.000000   61.000000    61.000000
# mean    81.114754  128.852459  180.803279  178.934426     0.186156
# std     45.870142   26.163483   58.256851   21.960471     0.095580
# min      1.000000   28.000000   36.000000  115.000000     0.026579
# 25%     66.000000  116.000000  185.000000  168.000000     0.121986
# 50%     83.000000  128.000000  206.000000  182.000000     0.180522
# 75%     94.000000  144.000000  217.000000  194.000000     0.227968
# max    206.000000  193.000000  241.000000  216.000000     0.516031
#
#        max_in_box  mean_global  top90_coverage  top90_recall  top95_coverage  \
# count   61.000000    61.000000       61.000000     61.000000       61.000000
# mean     0.579367     0.144361        0.123418      0.143080        0.117097
# std      0.271995     0.040944        0.096734      0.114815        0.107825
# min      0.036002     0.058169        0.000000      0.000000        0.000000
# 25%      0.403770     0.119699        0.038755      0.052941        0.014342
# 50%      0.618214     0.141132        0.114281      0.141667        0.107720
# 75%      0.737059     0.163235        0.193622      0.196320        0.180932
# max      1.000000     0.273448        0.323009      0.556133        0.412572
#
#        top95_recall  top99_coverage  top99_recall
# count     61.000000       61.000000     61.000000
# mean       0.068326        0.062995      0.007496
# std        0.070547        0.133870      0.017396
# min        0.000000        0.000000      0.000000
# 25%        0.011671        0.000000      0.000000
# 50%        0.058147        0.000000      0.000000
# 75%        0.092871        0.027439      0.004221
# max        0.390188        0.585366      0.105051
#
# [Result] Per-label statistics (mean over boxes):
#                   mean_in_box  max_in_box  mean_global  top90_coverage  \
# label
# Cardiomegaly         0.228701    0.703796     0.160336        0.167301
# Pleural effusion     0.092109    0.304311     0.109048        0.026414
#
#                   top90_recall  top95_coverage  top95_recall  top99_coverage  \
# label
# Cardiomegaly          0.181749        0.159755      0.088638        0.089717
# Pleural effusion      0.057601        0.022801      0.023425        0.003925
#
#                   top99_recall
# label
# Cardiomegaly          0.010594
# Pleural effusion      0.000648

# %%
df_label
# Out:
#                   mean_in_box  max_in_box  mean_global  top90_coverage  \
# label
# Cardiomegaly         0.228701    0.703796     0.160336        0.167301
# Pleural effusion     0.092109    0.304311     0.109048        0.026414
#
#                   top90_recall  top95_coverage  top95_recall  top99_coverage  \
# label
# Cardiomegaly          0.181749        0.159755      0.088638        0.089717
# Pleural effusion      0.057601        0.022801      0.023425        0.003925
#
#                   top99_recall
# label
# Cardiomegaly          0.010594
# Pleural effusion      0.000648

# %%
os.makedirs('/home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/evaluate_heatmaps_grad_crossattn', exist_ok=True)

# %%
# Optionally, save CSVs for deeper analysis
out_full = Path("/home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/evaluate_heatmaps_grad_crossattn/heatmap_eval_per_box.csv")
out_label = Path("/home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/evaluate_heatmaps_grad_crossattn/heatmap_eval_per_label.csv")
df_res.to_csv(out_full, index=False)
df_label.to_csv(out_label)
print(f"\n[Output] Saved per-box results to: {out_full}")
print(f"[Output] Saved per-label summary to: {out_label}")
# Out:
# [Output] Saved per-box results to: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/evaluate_heatmaps_grad_crossattn/heatmap_eval_per_box.csv
# [Output] Saved per-label summary to: /home/woody/iwi5/iwi5362h/ALBEF/results/zero_shot_vindr_results/evaluate_heatmaps_grad_crossattn/heatmap_eval_per_label.csv

# %%
df_res
