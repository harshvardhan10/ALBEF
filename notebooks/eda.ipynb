# %%
from pathlib import Path
import torch

# %%
image_id = "e0dc2e79105ad93532484e956ef8a71a"
heatmaps_dir = Path("../results/zero_shot_vindr_results/heatmaps_vindr")
p = heatmaps_dir / f"{image_id}.pt"

# %%
obj = torch.load(p, map_location="cpu")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 obj = torch.load(p, map_location="cpu")
#
# File ~/Documents/fau/thesis/thesis-codebase/.venv/lib/python3.9/site-packages/torch/serialization.py:579, in load(f, map_location, pickle_module, **pickle_load_args)
#     576 if 'encoding' not in pickle_load_args.keys():
#     577     pickle_load_args['encoding'] = 'utf-8'
# --> 579 with _open_file_like(f, 'rb') as opened_file:
#     580     if _is_zipfile(opened_file):
#     581         # The zipfile reader is going to advance the current file position.
#     582         # If we want to actually tail call to torch.jit.load, we need to
#     583         # reset back to the original position.
#     584         orig_position = opened_file.tell()
#
# File ~/Documents/fau/thesis/thesis-codebase/.venv/lib/python3.9/site-packages/torch/serialization.py:230, in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# File ~/Documents/fau/thesis/thesis-codebase/.venv/lib/python3.9/site-packages/torch/serialization.py:211, in _open_file.__init__(self, name, mode)
#     210 def __init__(self, name, mode):
# --> 211     super(_open_file, self).__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/zero_shot_vindr_results/heatmaps_vindr/e0dc2e79105ad93532484e956ef8a71a.pt'

# %%
# !pwd
# Out:
# /home/harsh/Documents/fau/thesis/thesis-codebase/ALBEF/notebooks
